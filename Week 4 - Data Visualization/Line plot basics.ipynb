# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])

# %%
plt.plot(months,sales)
plt.show()

# %%
plt.plot(months,sales)
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(months,sales)
plt.title('Month vs Sales\n',fontdict={'color':'purple','fontsize':20,'fontweight':21})

plt.xlabel('Months',fontdict={'color':'Green','fontsize':20,'fontweight':21})

plt.ylabel('Sales',fontdict={'color':'Green','fontsize':20,'fontweight':21})

for xy in zip(months, sales):
    plt.annotate(s = "{}K".format(xy[1]//1000), xy = xy,  textcoords='data')



plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(months,sales)
plt.title('Month vs Sales\n',fontdict={'color':'purple','fontsize':20,'fontweight':21})

plt.xlabel('Months',fontdict={'color':'Green','fontsize':20,'fontweight':21})

plt.ylabel('Sales',fontdict={'color':'Green','fontsize':20,'fontweight':21})

for xy in zip(months, sales):
    plt.annotate(s = "{}K".format(xy[1]//1000), xy = xy,  textcoords='data')



plt.xticks(rotation=90)
plt.show()
