# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
sales=pd.read_excel("/home/barani/Downloads/sales(1).xlsx")

# %%
sales
# Out:
#           Market             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# ...

# %%
sales.head()
# Out:
#    Market           Region  No_of_Orders    Profit     Sales
# 0  Africa   Western Africa           251 -12901.51  78476.06
# 1  Africa  Southern Africa            85  11768.58  51319.50
# 2  Africa     North Africa           182  21643.08  86698.89
# 3  Africa   Eastern Africa           110   8013.04  44182.60
# 4  Africa   Central Africa           103  15606.30  61689.99

# %%
sales.head(9)
# Out:
#          Market             Region  No_of_Orders    Profit      Sales
# 0        Africa     Western Africa           251 -12901.51   78476.06
# 1        Africa    Southern Africa            85  11768.58   51319.50
# 2        Africa       North Africa           182  21643.08   86698.89
# 3        Africa     Eastern Africa           110   8013.04   44182.60
# 4        Africa     Central Africa           103  15606.30   61689.99
# 5  Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6  Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7  Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8  Asia Pacific            Oceania           646  54734.02  408002.98

# %%
sales[["Sales","Profit"]].plot(kind="box", subplots=True)
plt.show()

# %%
sale2=sales[["Sales","Profit"]]

# %%
sale2
# Out:
#         Sales    Profit
# 0    78476.06 -12901.51
# 1    51319.50  11768.58
# 2    86698.89  21643.08
# 3    44182.60   8013.04
# 4    61689.99  15606.30
# 5   124312.24 -16766.90
# 6   351806.60  67998.76
# 7   329751.38  20948.84
# 8   408002.98  54734.02
# 9   315390.77  72805.10
# 10    8190.74  -2649.76
# 11  656637.14  82091.27
# 12  215703.93  18911.49
# 13  252969.09  43237.44
# 14  108258.93  25050.69
# 15  210710.49  12377.59
# 16  461670.28  74679.54
# 17  116333.05  13529.59
# 18  251991.83  44303.65
# 19  148771.91  19991.83
# 20  264973.98  47462.04
# 21  170416.31  33697.43
# 22   26298.81   7246.62

# %%
sales = pd.read_excel('/home/barani/Downloads/sales(1).xlsx', index_col = [1])

# %%
sales
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Western Africa           Africa           251 -12901.51   78476.06
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Western Asia       Asia Pacific           382 -16766.90  124312.24
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77
# Central Asia       Asia Pacific            37  -2649.76    8190.74
# Western Europe           Europe           964  82091.27  656637.14
# Southern Europe          Europe           338  18911.49  215703.93
# ...

# %%
sales.loc["Southern Asia"] #Displaying the entire data of the Southern Asia
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit               67998.8
# Sales                 351807
# Name: Southern Asia, dtype: object

# %%
sales.loc["Southern Asia","Sales"] #displaying only the sales data of the Southern Asia
# Out:
# 351806.6

# %%
sales.iloc[6] #Displaying the data based on the row number
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit               67998.8
# Sales                 351807
# Name: Southern Asia, dtype: object

# %%
sales.iloc[6,3]#Displaying the data based on the row and column number
# Out:
# 351806.6

# %% [markdown]
# ### Slicing

# %%
sales.loc[:,["Profit","Sales"]].head() #slicing some columns
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50
# North Africa     21643.08  86698.89
# Eastern Africa    8013.04  44182.60
# Central Africa   15606.30  61689.99

# %%
sales.iloc[:,[2,3]].head() #Slicing based on the column Number
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50
# North Africa     21643.08  86698.89
# Eastern Africa    8013.04  44182.60
# Central Africa   15606.30  61689.99

# %%
sales.loc[["Southeastern Asia","Oceania"],:] #Slicing the row based on the index name
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98

# %%
sales.iloc[[7,8],:] #Slicing the row based on the row number
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98

# %%
sales.loc[["Southeastern Asia","Oceania"],["Profit","Sales"]] #Slicing both rows and Column
# Out:
#                      Profit      Sales
# Region
# Southeastern Asia  20948.84  329751.38
# Oceania            54734.02  408002.98

# %%
sales.iloc[[7,8],[2,3]]
# Out:
#                      Profit      Sales
# Region
# Southeastern Asia  20948.84  329751.38
# Oceania            54734.02  408002.98

# %%
sales2=sales.iloc[::2,:]
sales2
# Out:
#                        Market  No_of_Orders    Profit      Sales
# Region
# Western Africa         Africa           251 -12901.51   78476.06
# North Africa           Africa           182  21643.08   86698.89
# Central Africa         Africa           103  15606.30   61689.99
# Southern Asia    Asia Pacific           469  67998.76  351806.60
# Oceania          Asia Pacific           646  54734.02  408002.98
# Central Asia     Asia Pacific            37  -2649.76    8190.74
# Southern Europe        Europe           338  18911.49  215703.93
# Eastern Europe         Europe           241  25050.69  108258.93
# Central America         LATAM           930  74679.54  461670.28
# Western US               USCA           490  44303.65  251991.83
# Eastern US               USCA           443  47462.04  264973.98
# Canada                   USCA            49   7246.62   26298.81

# %%
sales2.iloc[1:,:]
# Out:
#                        Market  No_of_Orders    Profit      Sales
# Region
# North Africa           Africa           182  21643.08   86698.89
# Central Africa         Africa           103  15606.30   61689.99
# Southern Asia    Asia Pacific           469  67998.76  351806.60
# Oceania          Asia Pacific           646  54734.02  408002.98
# Central Asia     Asia Pacific            37  -2649.76    8190.74
# Southern Europe        Europe           338  18911.49  215703.93
# Eastern Europe         Europe           241  25050.69  108258.93
# Central America         LATAM           930  74679.54  461670.28
# Western US               USCA           490  44303.65  251991.83
# Eastern US               USCA           443  47462.04  264973.98
# Canada                   USCA            49   7246.62   26298.81

# %%
sales[(sales["Market"].isin (["USCA","Europe"])) & (sales.Sales>250000)] 

#filtering the USCA and Europe region with the sales amount greater than 250K
# Out:
#                  Market  No_of_Orders    Profit      Sales
# Region
# Western Europe   Europe           964  82091.27  656637.14
# Northern Europe  Europe           367  43237.44  252969.09
# Western US         USCA           490  44303.65  251991.83
# Eastern US         USCA           443  47462.04  264973.98

# %%
sales[sales["Market","Profit"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Market', 'Profit')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-6df57f88c523> in <module>()
# ...
